# %%
import pandas as pd

# %%
df= pd.read_csv('ESPN_Cricinfo.csv')

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10           SPD Smith (AUS)  2010-2024  107   191  25   9634   239  58.03
# ...

# %%
df = df.rename(columns = {'Mat':'Matches_Played','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'batting strike rate'})

# %%
df
# Out:
#                       Player       Span  Matches_Played  Inns  Not_Outs  \
# 0           DG Bradman (AUS)  1928-1948              52    80        10
# 1             HC Brook (ENG)  2022-2023              12    20         1
# 2             AC Voges (AUS)  2015-2016              20    31         7
# 3            RG Pollock (SA)  1963-1970              23    41         4
# 4            GA Headley (WI)  1930-1954              22    40         4
# 5          H Sutcliffe (ENG)  1924-1935              54    84         9
# 6            E Paynter (ENG)  1931-1939              20    31         5
# 7        KF Barrington (ENG)  1955-1968              82   131        15
# 8             ED Weekes (WI)  1948-1958              48    81         5
# 9           WR Hammond (ENG)  1927-1947              85   140        16
# 10           SPD Smith (AUS)  2010-2024             107   191        25
# 11            GS Sobers (WI)  1954-1974              93   160        21
# ...

# %%
df.describe()
# Out:
#        Matches_Played        Inns   Not_Outs          Runs        Ave  \
# count       62.000000   62.000000  62.000000     62.000000  62.000000
# mean        80.145161  135.774194  14.129032   6427.645161  53.693387
# std         50.829463   86.533310  11.145070   4016.226269   7.205234
# min         12.000000   20.000000   1.000000    990.000000  48.000000
# 25%         30.250000   51.500000   5.250000   2379.000000  49.397500
# 50%         79.000000  134.500000  12.000000   6520.500000  51.735000
# 75%        117.750000  196.250000  19.000000   8844.000000  56.477500
# max        200.000000  329.000000  49.000000  15921.000000  99.940000
#
#              100         50          0           4s         6s
# count  62.000000  62.000000  62.000000    62.000000  62.000000
# mean   19.354839  28.596774   7.806452   653.338710  27.387097
# std    12.363480  18.626140   5.536285   522.874023  27.148864
# min     1.000000   3.000000   1.000000    37.000000   0.000000
# ...

# %%
df['Inns'][0]
# Out:
# 80

# %%
print(pd.__version__)
# Out:
# 2.2.0

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches_Played         False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# batting strike rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df.describe()
# Out:
#        Matches_Played        Inns   Not_Outs          Runs        Ave  \
# count       62.000000   62.000000  62.000000     62.000000  62.000000
# mean        80.145161  135.774194  14.129032   6427.645161  53.693387
# std         50.829463   86.533310  11.145070   4016.226269   7.205234
# min         12.000000   20.000000   1.000000    990.000000  48.000000
# 25%         30.250000   51.500000   5.250000   2379.000000  49.397500
# 50%         79.000000  134.500000  12.000000   6520.500000  51.735000
# 75%        117.750000  196.250000  19.000000   8844.000000  56.477500
# max        200.000000  329.000000  49.000000  15921.000000  99.940000
#
#              100         50          0           4s         6s
# count  62.000000  62.000000  62.000000    62.000000  62.000000
# mean   19.354839  28.596774   7.806452   653.338710  27.387097
# std    12.363480  18.626140   5.536285   522.874023  27.148864
# min     1.000000   3.000000   1.000000    37.000000   0.000000
# ...

# %%
df.drop_duplicates()
# Out:
#                       Player       Span  Matches_Played  Inns  Not_Outs  \
# 0           DG Bradman (AUS)  1928-1948              52    80        10
# 1             HC Brook (ENG)  2022-2023              12    20         1
# 2             AC Voges (AUS)  2015-2016              20    31         7
# 3            RG Pollock (SA)  1963-1970              23    41         4
# 4            GA Headley (WI)  1930-1954              22    40         4
# 5          H Sutcliffe (ENG)  1924-1935              54    84         9
# 6            E Paynter (ENG)  1931-1939              20    31         5
# 7        KF Barrington (ENG)  1955-1968              82   131        15
# 8             ED Weekes (WI)  1948-1958              48    81         5
# 9           WR Hammond (ENG)  1927-1947              85   140        16
# 10           SPD Smith (AUS)  2010-2024             107   191        25
# 11            GS Sobers (WI)  1954-1974              93   160        21
# ...

# %%
df[df['Player'].isin(['DG Bradman (AUS)','DR Jardine (ENG)'])]
# Out:
#               Player       Span  Matches_Played  Inns  Not_Outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948              52    80        10  6996
# 61  DR Jardine (ENG)  1928-1934              22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced batting strike rate  100  50  0   4s  \
# 0                 334  99.94       9800+                58.6   29  13  7  626
# 61                127  48.00       2110+               25.59    1  10  2   53
#
#     6s
# 0    6
# 61   0

# %%
df['Starting_year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Ending_year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                       Player       Span  Matches_Played  Inns  Not_Outs  \
# 0           DG Bradman (AUS)  1928-1948              52    80        10
# 1             HC Brook (ENG)  2022-2023              12    20         1
# 2             AC Voges (AUS)  2015-2016              20    31         7
# 3            RG Pollock (SA)  1963-1970              23    41         4
# 4            GA Headley (WI)  1930-1954              22    40         4
# 5          H Sutcliffe (ENG)  1924-1935              54    84         9
# 6            E Paynter (ENG)  1931-1939              20    31         5
# 7        KF Barrington (ENG)  1955-1968              82   131        15
# 8             ED Weekes (WI)  1948-1958              48    81         5
# 9           WR Hammond (ENG)  1927-1947              85   140        16
# 10           SPD Smith (AUS)  2010-2024             107   191        25
# 11            GS Sobers (WI)  1954-1974              93   160        21
# ...

# %%
df = df.drop(['Span'],axis= 1)

# %%
df
# Out:
#                       Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)              52    80        10   6996
# 1             HC Brook (ENG)              12    20         1   1181
# 2             AC Voges (AUS)              20    31         7   1485
# 3            RG Pollock (SA)              23    41         4   2256
# 4            GA Headley (WI)              22    40         4   2190
# 5          H Sutcliffe (ENG)              54    84         9   4555
# 6            E Paynter (ENG)              20    31         5   1540
# 7        KF Barrington (ENG)              82   131        15   6806
# 8             ED Weekes (WI)              48    81         5   4455
# 9           WR Hammond (ENG)              85   140        16   7249
# 10           SPD Smith (AUS)             107   191        25   9634
# 11            GS Sobers (WI)              93   160        21   8032
# 12        KC Sangakkara (SL)             134   233        17  12400
# ...

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat= ')').str[0]

# %%
df
# Out:
#                       Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)              52    80        10   6996
# 1             HC Brook (ENG)              12    20         1   1181
# 2             AC Voges (AUS)              20    31         7   1485
# 3            RG Pollock (SA)              23    41         4   2256
# 4            GA Headley (WI)              22    40         4   2190
# 5          H Sutcliffe (ENG)              54    84         9   4555
# 6            E Paynter (ENG)              20    31         5   1540
# 7        KF Barrington (ENG)              82   131        15   6806
# 8             ED Weekes (WI)              48    81         5   4455
# 9           WR Hammond (ENG)              85   140        16   7249
# 10           SPD Smith (AUS)             107   191        25   9634
# 11            GS Sobers (WI)              93   160        21   8032
# 12        KC Sangakkara (SL)             134   233        17  12400
# ...

# %%
df['Player'] = df['Player'].str.split(pat='(' ).str[0]

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8          ED Weekes               48    81         5   4455
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# ...

# %%
df.head()
# Out:
#         Player  Matches_Played  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0  DG Bradman               52    80        10  6996                334
# 1    HC Brook               12    20         1  1181                186
# 2    AC Voges               20    31         7  1485               269*
# 3  RG Pollock               23    41         4  2256                274
# 4  GA Headley               22    40         4  2190               270*
#
#      Ave Balls_Faced batting strike rate  100  50  0   4s  6s Starting_year  \
# 0  99.94       9800+                58.6   29  13  7  626   6          1928
# 1  62.15        1287               91.76    4   7  1  141  23          2022
# 2  61.87        2667               55.68    5   4  2  186   5          2015
# 3  60.97       1707+               54.48    7  11  1  246  11          1963
# 4  60.83        416+                  56   10   5  2  104   1          1930
#
#   Ending_year Country
# 0        1948     AUS
# 1        2023     ENG
# ...

# %%
df = df.rename(columns= {'Ending_year': 'Final_year'})

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8          ED Weekes               48    81         5   4455
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# batting strike rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year           object
# Final_year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat= '*').str[0]

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8          ED Weekes               48    81         5   4455
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# batting strike rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year           object
# Final_year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced             object
# batting strike rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year           object
# Final_year              object
# Country                 object
# dtype: object

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8          ED Weekes               48    81         5   4455
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat= '+').str[0]

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8          ED Weekes               48    81         5   4455
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df = df.drop([8,14,54],axis=0)

# %%
df
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 9         WR Hammond               85   140        16   7249
# 10         SPD Smith              107   191        25   9634
# 11         GS Sobers               93   160        21   8032
# 12     KC Sangakkara              134   233        17  12400
# 13          JB Hobbs               61   102         7   5410
# 15          L Hutton               79   138        15   6971
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# batting strike rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year           object
# Final_year              object
# Country                 object
# dtype: object

# %%
df['batting strike rate'] = df['batting strike rate'].astype('float')

# %%
df = df.astype({'Starting_year' : 'int' , 'Final_year' : 'int' })

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# batting strike rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year            int32
# Final_year               int32
# Country                 object
# dtype: object

# %%
df['Career_length'] = df['Final_year'] - df['Starting_year']

# %%
df.dtypes
# Out:
# Player                  object
# Matches_Played           int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int32
# Ave                    float64
# Balls_Faced              int32
# batting strike rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Starting_year            int32
# Final_year               int32
# Country                 object
# Career_length            int32
# dtype: object

# %%
## Avg of Career Length

df['Career_length'].mean()
# Out:
# 13.288135593220339

# %%
df.to_csv('ESPN_Cricinfo_Final.csv',index= False)

# %%
df1=pd.read_csv('ESPN_Cricinfo_Final.csv')

# %%
df1
# Out:
#                Player  Matches_Played  Inns  Not_Outs   Runs  \
# 0         DG Bradman               52    80        10   6996
# 1           HC Brook               12    20         1   1181
# 2           AC Voges               20    31         7   1485
# 3         RG Pollock               23    41         4   2256
# 4         GA Headley               22    40         4   2190
# 5        H Sutcliffe               54    84         9   4555
# 6          E Paynter               20    31         5   1540
# 7      KF Barrington               82   131        15   6806
# 8         WR Hammond               85   140        16   7249
# 9          SPD Smith              107   191        25   9634
# 10         GS Sobers               93   160        21   8032
# 11     KC Sangakkara              134   233        17  12400
# 12          JB Hobbs               61   102         7   5410
# 13          L Hutton               79   138        15   6971
# ...
